# %% [markdown]
# # UNEMPLOYMENT ANALYSIS WITH PYTHON
# ## TASK-2
#
# Unemployment is measured by the unemployment rate which is the number of people who are unemployed as a percentage of the total labour force. We have seen a sharp increase in the unemployment rate during Covid-19, so analyzing the unemployment rate can be a good data science project.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath="Unemployment.csv"

# %%
df = pd.read_csv(filepath)

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %% [markdown]
# # CLEANING DATA

# %%
# Rename the columns of the DataFrame using the dictionary
df.rename(columns={"Region": "region", " Date": "date", " Frequency": "frequency", " Estimated Unemployment Rate (%)": "unemployment_rate", " Estimated Employed": "employed", " Estimated Labour Participation Rate (%)": "labour_participate_rate", "Area": "area"},inplace=True)

# %%
df
# Out:
#              region         date frequency  unemployment_rate    employed  \
# 0    Andhra Pradesh   31-05-2019   Monthly               3.65  11999139.0
# 1    Andhra Pradesh   30-06-2019   Monthly               3.05  11755881.0
# 2    Andhra Pradesh   31-07-2019   Monthly               3.75  12086707.0
# 3    Andhra Pradesh   31-08-2019   Monthly               3.32  12285693.0
# 4    Andhra Pradesh   30-09-2019   Monthly               5.17  12256762.0
# ..              ...          ...       ...                ...         ...
# 763             NaN          NaN       NaN                NaN         NaN
# 764             NaN          NaN       NaN                NaN         NaN
# 765             NaN          NaN       NaN                NaN         NaN
# 766             NaN          NaN       NaN                NaN         NaN
# 767             NaN          NaN       NaN                NaN         NaN
#
#      labour_participate_rate   area
# 0                      43.24  Rural
# ...

# %%
df.region.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', nan, 'Chandigarh'],
#       dtype=object)

# %%
df.area.unique()
# Out:
# array(['Rural', nan, 'Urban'], dtype=object)

# %%
df=df.dropna()

# %%
#df["date"] = pd.to_datetime(df["date"])  # Convert "date" column to datetime object
#df.set_index("date", inplace=True)  # Set "date" column as index

# %% [markdown]
# # PROCESSED DATA

# %%
df
# Out:
#              region         date frequency  unemployment_rate    employed  \
# 0    Andhra Pradesh   31-05-2019   Monthly               3.65  11999139.0
# 1    Andhra Pradesh   30-06-2019   Monthly               3.05  11755881.0
# 2    Andhra Pradesh   31-07-2019   Monthly               3.75  12086707.0
# 3    Andhra Pradesh   31-08-2019   Monthly               3.32  12285693.0
# 4    Andhra Pradesh   30-09-2019   Monthly               5.17  12256762.0
# ..              ...          ...       ...                ...         ...
# 749     West Bengal   29-02-2020   Monthly               7.55  10871168.0
# 750     West Bengal   31-03-2020   Monthly               6.67  10806105.0
# 751     West Bengal   30-04-2020   Monthly              15.63   9299466.0
# 752     West Bengal   31-05-2020   Monthly              15.22   9240903.0
# 753     West Bengal   30-06-2020   Monthly               9.86   9088931.0
#
#      labour_participate_rate   area
# 0                      43.24  Rural
# ...

# %%
df.describe()
# Out:
#             index  unemployment_rate      employed  labour_participate_rate
# count  740.000000         740.000000  7.400000e+02               740.000000
# mean   376.708108          11.787946  7.204460e+06                42.630122
# std    219.852758          10.721298  8.087988e+06                 8.111094
# min      0.000000           0.000000  4.942000e+04                13.330000
# 25%    184.750000           4.657500  1.190404e+06                38.062500
# 50%    383.500000           8.350000  4.744178e+06                41.160000
# 75%    568.250000          15.887500  1.127549e+07                45.505000
# max    753.000000          76.740000  4.577751e+07                72.570000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   index                    740 non-null    int64
#  1   region                   740 non-null    object
#  2   date                     740 non-null    object
#  3   frequency                740 non-null    object
#  4   unemployment_rate        740 non-null    float64
#  5   employed                 740 non-null    float64
#  6   labour_participate_rate  740 non-null    float64
#  7   area                     740 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 46.4+ KB

# %% [markdown]
# # DATA ANALYSIS

# %% [markdown]
# ### PAIR PLOT

# %%
# to visualize the relationship between the employment and unemployment rates and the labour participation rate

# Reset index
df = df.reset_index()

# Define columns for pair plot
cols = ["unemployment_rate", "employed", "labour_participate_rate"]

print(">> to visualize the relationship between the employment and unemployment rates and the labour participation rate >>")
# Create pair plot
sns.pairplot(df[cols])
# Out:
# >> to visualize the relationship between the employment and unemployment rates and the labour participation rate >>

# %% [markdown]
# ### PIE CHART

# %%
# group data by region and calculate average unemployment rate

avg_unemployment = df.groupby('region')['unemployment_rate'].mean()

# create a pie chart
fig, ax = plt.subplots(figsize=(12, 12))
ax.pie(avg_unemployment, labels=avg_unemployment.index, autopct='%1.1f%%')
ax.set_title('Average Unemployment Rate by Region')

plt.show()

# %% [markdown]
# ### SCATTER PLOT

# %%
# analyze the trend of unemployment rate over time by plotting the data as a scatter plot

plt.rcParams["figure.figsize"] = (20, 10)
plt.scatter(df['date'], df['unemployment_rate'])
plt.title('Unemployment Rate by Date',size=30)
plt.xlabel('Date',size=30)
plt.ylabel('Unemployment Rate (%)',size=30)
print(">> analyze the trend of unemployment rate over time by plotting the data as a scatter plot >>")
plt.show()
# Out:
# >> analyze the trend of unemployment rate over time by plotting the data as a scatter plot >>

# %% [markdown]
# ### BAR PLOT

# %%
# to show the unemployment rate for each region in the dataset

plt.rcParams["figure.figsize"] = (20, 10)
sns.barplot(x='region', y='unemployment_rate', data=df)
plt.title('Unemployment Rate by Region',size=20)
plt.xlabel('Region',size=20)
plt.ylabel('Unemployment Rate (%)',size=20)
# Get the bar plot
bar_plot = sns.barplot(x='region', y='unemployment_rate', data=df)
bar_plot.set_xticklabels(bar_plot.get_xticklabels(), rotation=90) # Rotate x-tick labels by 90 degrees
print(">> to analyse the unemployment rate for each region in the dataset >>")
plt.show()
# Out:
# >> to analyse the unemployment rate for each region in the dataset >>

# %% [markdown]
# ### BOX PLOT

# %%
# to analyse the outliers

# Create the box plot
sns.set_style("whitegrid")
fig, ax = plt.subplots(figsize=(30, 20))
sns.boxplot(data=df, x="region", y="unemployment_rate", hue="frequency", ax=ax)
ax.set_title("Unemployment Rate by Region and Frequency",size=30)
ax.set_ylabel("Unemployment Rate",size=30)
ax.set_xlabel("\nRegion",size=35)
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
ax.set_xticklabels(ax.get_xticklabels(), fontsize=30)
plt.subplots_adjust(wspace=0.5)
print(">> to analyse the outliers >>")
plt.show()
# Out:
# >> to analyse the outliers >>

# %% [markdown]
# ### HEAT MAP

# %%
# for finding the correlations

corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm")
print(">> to analyse the correlations >>")
plt.show()
# Out:
# >> to analyse the correlations >>

# %%
# to visualizes the unemployment rate by region and date

# Pivot the data to get the unemployment rate by region and date
df_pivot = pd.pivot_table(df, values='unemployment_rate', index='region', columns='date', aggfunc='mean')

# Create the heatmap
plt.figure(figsize=(20, 10))
sns.heatmap(df_pivot, cmap='YlGnBu')
plt.title('Unemployment Rate by Region and Date',size=20)
plt.xlabel('Date',size=20)
plt.ylabel('Region',size=20)
print(">> to visualizes the unemployment rate by region and date >>")
plt.show()
# Out:
# >> to visualizes the unemployment rate by region and date >>

# %%
# Print the first 5 rows to verify the data was loaded correctly
print(df.head())
print("\n\n")

# Get some basic statistics on the unemployment rate column
print(df['unemployment_rate'].describe())
print("\n")

# Calculate the average unemployment rate for each region
region_avg_unemp = df.groupby('region')['unemployment_rate'].mean()
print("Avg unemployment in each region:\n\n",region_avg_unemp)
print("\n\n")

# Calculate the overall average unemployment rate for the entire dataset
overall_avg_unemp = df['unemployment_rate'].mean()
print("Overall average unemployment rate:", overall_avg_unemp)
print("\n\n")

# Calculate the average unemployment rate by year
df['year'] = pd.DatetimeIndex(df['date']).year
yearly_avg_unemp = df.groupby('year')['unemployment_rate'].mean()
print("yearly avg unemployment: \n",yearly_avg_unemp)
# Out:
#    index          region         date frequency  unemployment_rate  \
# 0      0  Andhra Pradesh   31-05-2019   Monthly               3.65
# 1      1  Andhra Pradesh   30-06-2019   Monthly               3.05
# 2      2  Andhra Pradesh   31-07-2019   Monthly               3.75
# 3      3  Andhra Pradesh   31-08-2019   Monthly               3.32
# 4      4  Andhra Pradesh   30-09-2019   Monthly               5.17
#
#      employed  labour_participate_rate   area  year
# 0  11999139.0                    43.24  Rural  2019
# 1  11755881.0                    42.05  Rural  2019
# 2  12086707.0                    43.50  Rural  2019
# 3  12285693.0                    43.97  Rural  2019
# 4  12256762.0                    44.68  Rural  2019
#
#
#
# count    740.000000
# mean      11.787946
# std       10.721298
# min        0.000000
# 25%        4.657500
# 50%        8.350000
# 75%       15.887500
# max       76.740000
# Name: unemployment_rate, dtype: float64
#
#
# ...

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# ### After  analyzing  the  provided  dataset  on  unemployment,  it  was  found  that  the  average  unemployment  rate  across  all  regions  and  time  periods  was  11.79%.  Bihar  had  the  highest  average  unemployment  rate  at  18.92%,  while  Meghalaya  had  the  lowest  at  4.80%.  The overall  average  unemployment  rate  for  the  dataset  was  11.79%.  Looking  at  the  yearly  averages,  the  unemployment  rate  was  lower  in  2019  at  9.40%  compared  to  2020  where  it  was  15.10%.

# %% [markdown]
# ### ---------------------------------------------------------------------------------------------------------------------------------------------------------------
